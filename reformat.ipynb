# %%
import pandas as pd

df = pd.read_csv('data/patient-presentations-combined.csv')

df.head()
# Out:
#   Patient Presentation code                 Patient Presentation name  \
# 0                   PRES001                            Abdominal mass
# 1                   PRES002                            Abdominal pain
# 2                   PRES003                        Abdominal swelling
# 3                   PRES004  Abnormal development/developmental delay
# 4                   PRES005     Abnormal eating or exercise behaviour
#
#                                    combined_contexts
# 0  Primary care context\nA palpable abdominal mas...
# 1  Primary care context\nIdentifying an underlyin...
# 2  Primary care context\nPatients may describe a ...
# 3  Primary care context\nWhilst the primary care ...
# 4  Primary care context\nGeneral practice is ofte...

# %%
# get first 10 rows
df_reduced = df.head(10)

# %%
care_contexts = [
    'Primary care context',
    'Secondary care context', 
    'Paediatric care context',
    'Geriatric care context',
]

# %%
# Add new column for each care context and populate with an empty string
for context in care_contexts:
    df[context] = ''

# %%
df['Flagged'] = ''

# %%
df.head()
# Out:
#   Patient Presentation code                 Patient Presentation name  \
# 0                   PRES001                            Abdominal mass
# 1                   PRES002                            Abdominal pain
# 2                   PRES003                        Abdominal swelling
# 3                   PRES004  Abnormal development/developmental delay
# 4                   PRES005     Abnormal eating or exercise behaviour
#
#                                    combined_contexts Primary care context  \
# 0  Primary care context\nA palpable abdominal mas...
# 1  Primary care context\nIdentifying an underlyin...
# 2  Primary care context\nPatients may describe a ...
# 3  Primary care context\nWhilst the primary care ...
# 4  Primary care context\nGeneral practice is ofte...
#
#   Secondary care context Paediatric care context Geriatric care context  \
# 0
# 1
# 2
# 3
# 4
#
#   Flagged
# 0
# 1
# 2
# 3
# 4

# %%
df_reduced = df.head(10)

# %%
import re

def extract_care_contexts(text):
    """Extract care contexts from combined text and return as dictionary."""
    
    # Initialize all contexts as empty strings
    contexts = {
        'primary': '',
        'secondary': '',
        'paediatric': '',
        'geriatric': ''
    }
    
    # Find all context sections using regex with lookahead
    patterns = {
        'primary': r'Primary care context\n(.*?)(?=\n(?:Secondary|Paediatric|Geriatric) care context|\Z)',
        'secondary': r'Secondary care context\n(.*?)(?=\n(?:Primary|Paediatric|Geriatric) care context|\Z)',
        'paediatric': r'Paediatric care context\n(.*?)(?=\n(?:Primary|Secondary|Geriatric) care context|\Z)',
        'geriatric': r'Geriatric care context\n(.*?)(?=\n(?:Primary|Secondary|Paediatric) care context|\Z)'
    }
    
    for context_key, pattern in patterns.items():
        match = re.search(pattern, text, re.DOTALL)
        if match:
            contexts[context_key] = match.group(1).strip()
    
    return contexts

# %%
example = extract_care_contexts(df['combined_contexts'][0])

# %%
from openai import OpenAI
from utils import TemplateManager

from dotenv import load_dotenv
load_dotenv()

import os
api_key = os.getenv('OPENAI_API_KEY')

# %%
import asyncio
from openai import AsyncOpenAI

class Reformatron:
    def __init__(self, api_key):
        self.client = AsyncOpenAI(api_key=api_key)
        self.prompt_manager = TemplateManager('./prompts/')
        self.user_prompt = self.prompt_manager.get_template('input-prompt.jinja')
        self.system_prompt = self.prompt_manager.get_template('system-prompt.jinja')

    async def reformat(self, args):
        """Reformat the care contexts using OpenAI API."""
        
        response = await self.client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": self.system_prompt.render()},
                {"role": "user", "content": self.user_prompt.render(**args)}
            ],
            max_tokens=2048,
            temperature=0.0,
        )
        
        return response.choices[0].message.content

# %%
reformatron = Reformatron(api_key)
output = reformatron.reformat(example)

# %% [markdown]
# # Evaluation

# %%
from difflib import SequenceMatcher

def clean_text(text: str) -> str:
    text = text.lower()
    text = re.sub(r'(\d)-([a-z])', r'\1§\2', text)
    text = re.sub(r'[^a-z0-9\s§]', '', text)
    text = re.sub(r'\s+', ' ', text)
    text = text.replace('§', '-')
    text = text.strip()
    
    return text

def evaluate(original, reformatted):
    cleaned_original = clean_text(original)
    cleaned_output = clean_text(reformatted)

    original_words = cleaned_original.split()
    output_words = cleaned_output.split()

    word_ratio = SequenceMatcher(None, original_words, output_words).ratio()
    character_ratio = SequenceMatcher(None, cleaned_original, cleaned_output).ratio()

    return {
        'word_ratio': word_ratio,
        'character_ratio': character_ratio,
    }

# %%
evaluate(df['combined_contexts'][0], output)
# Out:
# {'word_ratio': 0.980225988700565, 'character_ratio': 0.3238216021982668}

# %%
print(output)
# Out:
# # Primary care context
# A palpable abdominal mass may be apparent to a patient/parent or identified by the GP when a patient presents with other symptoms such as a change in bowel habit, urinary symptoms, weight loss, vomiting or pain.
#
# Think about the symptoms you would ask about, and the key features that are of importance in different groups such as:
#
# - children
# - patients who ovulate
# - patients who have undergone surgery
# - patients with underlying diagnoses such as inflammatory bowel disease or prostatism.
#
# Practice abdominal examination where you can, learning to identify and characterize the location, extent and consistency of abdominal masses including organomegaly.
#
# Speak to your GP tutor about what investigations you might utilise including:
#
# - bloods
# - FIT samples
# - urinalysis
# - imaging.
#
# Review the 2WW criteria for referral directly to specialities such as Gynaecology, Gastroenterology, Urology and USS.
#
# # Secondary care context
# Presentations of abdominal masses in secondary care can cover a broad range of pathologies. In the acute setting, you are most likely to encounter abdominal masses in the emergency department or acute surgical units where the mass is usually accompanied with abdominal pain.
#
# In these situations, a thorough history and abdominal examination is essential to help establish the location and the cause of the abdominal mass.
#
# You may also encounter patients who have bowel obstruction secondary to an abdominal mass. These patients are often very unwell; in addition to abdominal pain, they often experience:
#
# - nausea
# - vomiting
# - reduced/no flatus.
#
# On examination, their abdomen is usually tender and bowel sounds are usually absent or tinkling. This is a surgical emergency due to the impending risk of bowel perforation.
#
# Causes of abdominal masses can be broken down into malignant and non-malignant causes.
#
# Non-malignant disease processes include:
#
# - hernias
# - abdominal aortic aneurysm
# - diverticulitis
# - Crohn’s disease
# - ovarian cyst in women.
#
# Various malignancies can present with an abdominal mass, including:
#
# - stomach
# - colorectal
# - renal
# - liver cancers.
#
# # Paediatric care context
#
# # Geriatric care context
# Older patients with abdominal masses are commonly referred to Geriatric Clinics and the usual differentials apply, but commonly constipation may be a cause.
#
# Malignancy, hernia, abscess, AAA are also commonly encountered.
#
# Severe kyphoscoliosis may also distort the usual anatomy causing 'false' palpable masses.

# %%
evaluate(df['combined_contexts'][1], output)
# Out:
# {'word_ratio': 0.9938837920489296, 'character_ratio': 0.993006993006993}

# %%
def add_entry(df, entry, index, evaluation_score, threshold=0.9):
    # get content
    parsed_content = {}
    current_heading_key = None
    current_lines = []

    for line in entry.splitlines():
        # Check if the line is a markdown header (e.g., "# Header Name")
        # This regex matches lines starting with one or more '#' followed by a space
        match = re.match(r'^(#+)\s+(.*)', line)
        if match:
            # If we were accumulating content for a previous header, store it
            if current_heading_key:
                parsed_content[current_heading_key] = "\n".join(current_lines).strip()

            # Set the new header key (text after '# ' and stripped)
            current_heading_key = match.group(2).strip()
            current_lines = []  # Reset lines for the new section
        elif current_heading_key:
            # If it's not a header line and we are under a heading, accumulate the line
            current_lines.append(line)

    # Store content for the last section after the loop finishes
    if current_heading_key:
        parsed_content[current_heading_key] = "\n".join(current_lines).strip()

    # Populate df
    for heading, content_text in parsed_content.items():
        if heading in df.columns:
            df.loc[index, heading] = content_text
        else:
            print(f"Warning: Header '{heading}' from text not found in DataFrame columns.")

    if evaluation_score['word_ratio'] >= threshold:
        df.loc[index, 'Flagged'] = 'No'
    else:
        print(f"Entry at index {index} did not meet the threshold. Word ratio: {evaluation_score['word_ratio']}")
        df.loc[index, 'Flagged'] = 'Yes'

# %%
async def process_single_entry(df, reformatron, index, row):
    """Process a single entry asynchronously."""
    combined_contexts = row['combined_contexts']
    if pd.isna(combined_contexts) or not combined_contexts.strip():
        return
    
    # Extract care contexts
    contexts = extract_care_contexts(combined_contexts)
    
    # Reformat using OpenAI API
    reformatted_text = await reformatron.reformat(contexts)

    evaluation_score = evaluate(combined_contexts, reformatted_text)
    
    # Add entry to DataFrame
    add_entry(df, reformatted_text, index, evaluation_score)

async def async_pipeline(df, reformatron, max_concurrent=10):
    """
    Process DataFrame entries asynchronously with controlled concurrency.
    
    Args:
        df: DataFrame to process
        reformatron: Reformatron instance
        max_concurrent: Maximum number of concurrent API calls (default: 10)
    """
    semaphore = asyncio.Semaphore(max_concurrent)
    
    async def process_with_semaphore(index, row):
        async with semaphore:
            await process_single_entry(df, reformatron, index, row)
    
    # Create tasks for all entries
    tasks = [
        process_with_semaphore(index, row) 
        for index, row in df.iterrows()
    ]
    
    # Execute all tasks concurrently
    await asyncio.gather(*tasks)
    
    return df

# %%
reformatron = Reformatron(api_key=api_key)

result_df = await async_pipeline(df, reformatron, max_concurrent=200)
# Out:
# /usr/lib/python3.12/asyncio/events.py:36: RuntimeWarning: coroutine 'main' was never awaited
#   def __init__(self, callback, args, loop, context=None):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Entry at index 39 did not meet the threshold. Word ratio: 0.7894201424211598
# Entry at index 51 did not meet the threshold. Word ratio: 0.8773006134969326

# %%
result_df.head()
# Out:
#   Patient Presentation code                 Patient Presentation name  \
# 0                   PRES001                            Abdominal mass
# 1                   PRES002                            Abdominal pain
# 2                   PRES003                        Abdominal swelling
# 3                   PRES004  Abnormal development/developmental delay
# 4                   PRES005     Abnormal eating or exercise behaviour
#
#                                    combined_contexts  \
# 0  Primary care context\nA palpable abdominal mas...
# 1  Primary care context\nIdentifying an underlyin...
# 2  Primary care context\nPatients may describe a ...
# 3  Primary care context\nWhilst the primary care ...
# 4  Primary care context\nGeneral practice is ofte...
#
#                                 Primary care context  \
# 0  A palpable abdominal mass may be apparent to a...
# 1  Identifying an underlying cause in patients wh...
# 2  Patients may describe a sensation of swelling ...
# 3  Whilst the primary care team are involved in c...
# 4  General practice is often the first place that...
#
#                               Secondary care context  \
# 0  Presentations of abdominal masses in secondary...
# 1  Abdominal pain is one of the most common prese...
# 2  Abdominal swelling is a common and potentially...
# 3  'Childhood Development’ is usually defined as ...
# 4  Eating disorders are common in children and yo...
#
#                              Paediatric care context  \
# 0
# 1  Abdominal pain is one of the most frequent com...
# 2
# 3  It is important to understand the normal patte...
# 4
#
#                               Geriatric care context Flagged
# 0  Older patients with abdominal masses are commo...      No
# 1  Again, the usual differentials apply, but comm...      No
# 2           AAA; ascites; malignancy, heart failure;      No
# 3                                                         No
# 4  In older people, consider the following differ...      No

# %%
def pipeline(df, reformatron):
    for index, row in df.iterrows():
        combined_contexts = row['combined_contexts']
        if pd.isna(combined_contexts) or not combined_contexts.strip():
            continue
        
        # Extract care contexts
        contexts = extract_care_contexts(combined_contexts)
        
        # Reformat using OpenAI API
        reformatted_text = reformatron.reformat(contexts)

        evaluation_score = evaluate(combined_contexts, reformatted_text)
        
        # Add entry to DataFrame
        add_entry(df, reformatted_text, index, evaluation_score)
    
    return df

# %%
print(df['Primary care context'][0])
# Out:
# A palpable abdominal mass may be apparent to a patient/parent or identified by the GP when a patient presents with other symptoms such as a change in bowel habit, urinary symptoms, weight loss, vomiting or pain.
#
# Think about the symptoms you would ask about, and the key features that are of importance in different groups such as:
#
# - children
# - patients who ovulate
# - patients who have undergone surgery
# - patients with underlying diagnoses such as inflammatory bowel disease or prostatism.
#
# Practice abdominal examination where you can, learning to identify and characterize the location, extent and consistency of abdominal masses including organomegaly.
#
# Speak to your GP tutor about what investigations you might utilise including:
#
# - bloods
# - FIT samples
# - urinalysis
# - imaging.
#
# Review the 2WW criteria for referral directly to specialities such as Gynaecology, Gastroenterology, Urology and USS.

# %% [markdown]
# # Visualize potential differences

# %%
from rouge_score import rouge_scorer
import html
from IPython.display import HTML
from typing import List, Tuple, Set

def find_ngram_positions(text: str, n: int) -> List[Tuple[str, int]]:
    """Find all n-grams and their starting positions in the text."""
    words = text.split()
    ngrams = []
    for i in range(len(words) - n + 1):
        ngram = " ".join(words[i:i + n])
        ngrams.append((ngram, i))
    return ngrams

def get_matching_ngrams(reference: str, candidate: str, n: int) -> Set[str]:
    """Find all matching n-grams between reference and candidate texts."""
    ref_ngrams = set(ngram for ngram, _ in find_ngram_positions(reference, n))
    cand_ngrams = set(ngram for ngram, _ in find_ngram_positions(candidate, n))
    return ref_ngrams.intersection(cand_ngrams)

def highlight_matches(text: str, matches: Set[str], n: int) -> str:
    """Highlight matching n-grams in the text using HTML spans."""
    words = text.split()
    highlighted = words.copy()
    
    # Find positions of matching n-grams
    ngram_positions = find_ngram_positions(text, n)
    matching_positions = []
    
    for ngram, pos in ngram_positions:
        if ngram in matches:
            matching_positions.extend(range(pos, pos + n))
    
    # Apply highlighting
    for i in range(len(words)):
        if i in matching_positions:
            highlighted[i] = f'<span style="background-color: yellow">{html.escape(words[i])}</span>'
        else:
            highlighted[i] = html.escape(words[i])
    
    return " ".join(highlighted)

def visualize_rouge_matches(reference: str, candidate: str, n: int = 1):
    """
    Visualize matching n-grams between reference and candidate texts.
    
    Args:
        reference: Reference text
        candidate: Candidate text to compare against reference
        n: Size of n-grams to compare (default: 1 for unigrams)
    
    Returns:
        IPython.display.HTML object with highlighted matching sequences
    """
    # Find matching n-grams
    matches = get_matching_ngrams(reference, candidate, n)
    
    # Highlight matches in both texts
    highlighted_ref = highlight_matches(reference, matches, n)
    highlighted_cand = highlight_matches(candidate, matches, n)
    
    # Calculate Rouge score
    scorer = rouge_scorer.RougeScorer([f'rouge{n}'], use_stemmer=True)
    scores = scorer.score(reference, candidate)
    rouge_score = scores[f'rouge{n}'].fmeasure
    
    # Create HTML output
    html_output = f"""
    <div style="font-family: monospace; white-space: pre-wrap;">
        <h3>Rouge-{n} Score: {rouge_score:.3f}</h3>
        <div style="margin: 10px 0;">
            <strong>Reference:</strong><br>
            {highlighted_ref}
        </div>
        <div style="margin: 10px 0;">
            <strong>Candidate:</strong><br>
            {highlighted_cand}
        </div>
    </div>
    """
    
    return HTML(html_output)

# %%
display(visualize_rouge_matches(cleaned_output, cleaned_original, n=3))
# Out:
#     <div style="font-family: monospace; white-space: pre-wrap;">
#         <h3>Rouge-3 Score: 0.977</h3>
#         <div style="margin: 10px 0;">
#             <strong>Reference:</strong><br>
#             <span style="background-color: yellow">primary</span> <span style="background-color: yellow">care</span> <span style="background-color: yellow">context</span> <span style="background-color: yellow">identifying</span> <span style="background-color: yellow">an</span> <span style="background-color: yellow">underlying</span> <span style="background-color: yellow">cause</span> <span style="background-color: yellow">in</span> <span style="background-color: yellow">patients</span> <span style="background-color: yellow">who</span> <span style="background-color: yellow">have</span> <span style="background-color: yellow">difficulty</span> <span style="background-color: yellow">communicating</span> <span style="background-color: yellow">those</span> <span style="background-color: yellow">at</span> <span style="background-color: yellow">the</span> <span style="background-color: yellow">extremes</span> <span style="background-color: yellow">of</span> <span style="background-color: yellow">age</span> <span style="background-color: yellow">and</span> <span style="background-color: yellow">in</span> <span style="background-color: yellow">pregnancy</span> <span style="background-color: yellow">requires</span> <span style="background-color: yellow">careful</span> <span style="background-color: yellow">practice</span> <span style="background-color: yellow">and</span> <span style="background-color: yellow">skill</span> <span style="background-color: yellow">and</span> <span style="background-color: yellow">the</span> <span style="background-color: yellow">recent</span> <span style="background-color: yellow">shift</span> <span style="background-color: yellow">to</span> <span style="background-color: yellow">remote</span> <span style="background-color: yellow">consultation</span> <span style="background-color: yellow">has</span> <span style="background-color: yellow">exacerbated</span> <span style="background-color: yellow">this</span> <span style="background-color: yellow">consider</span> <span style="background-color: yellow">elements</span> <span style="background-color: yellow">of</span> <span style="background-color: yellow">the</span> <span style="background-color: yellow">narrative</span> <span style="background-color: yellow">examination</span> <span style="background-color: yellow">and</span> <span style="background-color: yellow">risk</span> <span style="background-color: yellow">assessment</span> <span style="background-color: yellow">that</span> <span style="background-color: yellow">would</span> <span style="background-color: yellow">suggest</span> <span style="background-color: yellow">the</span> <span style="background-color: yellow">acute</span> <span style="background-color: yellow">abdomen</span> <span style="background-color: yellow">requiring</span> <span style="background-color: yellow">urgent</span> <span style="background-color: yellow">surgical</span> <span style="background-color: yellow">or</span> <span style="background-color: yellow">gynaecological</span> <span style="background-color: yellow">assessment</span> <span style="background-color: yellow">and</span> <span style="background-color: yellow">ambulance</span> <span style="background-color: yellow">transfer</span> <span style="background-color: yellow">from</span> <span style="background-color: yellow">home</span> <span style="background-color: yellow">or</span> <span style="background-color: yellow">the</span> <span style="background-color: yellow">surgery</span> <span style="background-color: yellow">be</span> <span style="background-color: yellow">aware</span> <span style="background-color: yellow">of</span> <span style="background-color: yellow">common</span> <span style="background-color: yellow">causes</span> <span style="background-color: yellow">such</span> <span style="background-color: yellow">as</span> <span style="background-color: yellow">infantile</span> <span style="background-color: yellow">colic</span> <span style="background-color: yell ...

# %%
similarity
# Out:
# 0.8450644683999154

# %%
def word_level_similarity(text1, text2):
    """More forgiving of spelling corrections."""
    words1 = text1.split()
    words2 = text2.split()
    return SequenceMatcher(None, words1, words2).ratio()

word_level_similarity(cleaned_output, cleaned_original)
# Out:
# 0.980225988700565

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def bleu_similarity(original, reformatted):
    """BLEU score for content preservation."""
    reference = [original.split()]
    candidate = reformatted.split()
    
    # Use smoothing to handle short texts better
    smoothie = SmoothingFunction().method1
    return sentence_bleu(reference, candidate, smoothing_function=smoothie)

bleu_score = bleu_similarity(cleaned_original, cleaned_output)
print(f"BLEU score: {bleu_score:.4f}")
# Out:
# BLEU score: 0.9464

# %%
from difflib import SequenceMatcher

text1 = cleaned_original.split()
text2 = cleaned_output.split()

ratio = SequenceMatcher(None, text1, text2).ratio()
print(f"Similarity ratio: {ratio}")
# Out:
# Similarity ratio: 0.980225988700565

# %%
if len(text1) == len(text2):
    for i in range(len(text2)):
        if text1[i] != text2[i]:
            print(f"Word at index {i} changed: '{text1[i]}' -> '{text2[i]}'")
else:
    print("Word lists have different lengths, direct comparison might be misleading.")
    # Consider using difflib in this case (see below)
# Out:
# Word at index 69 changed: 'or' -> 'patients'
# Word at index 70 changed: 'have' -> 'with'
# Word at index 117 changed: 'and' -> 'imaging'
# Word at index 118 changed: 'imaging' -> 'review'
# Word at index 119 changed: 'review' -> 'the'
# Word at index 120 changed: 'the' -> '2ww'
# Word at index 121 changed: '2ww' -> 'criteria'
# Word at index 122 changed: 'criteria' -> 'for'
# Word at index 123 changed: 'for' -> 'referral'
# Word at index 124 changed: 'referral' -> 'directly'
# Word at index 125 changed: 'directly' -> 'to'
# Word at index 126 changed: 'to' -> 'specialities'
# Word at index 127 changed: 'specialities' -> 'such'
# Word at index 128 changed: 'such' -> 'as'
# Word at index 129 changed: 'as' -> 'gynaecology'
# Word at index 130 changed: 'gynaecology' -> 'gastroenterology'
# Word at index 131 changed: 'gastroenterology' -> 'urology'
# Word at index 132 changed: 'urology' -> 'and'
# Word at index 133 changed: 'and' -> 'uss'
# Word at index 134 changed: 'uss' -> 'secondary'
# Word at index 135 changed: 'secondary' -> 'care'
# Word at index 136 changed: 'care' -> 'context'
# Word at index 137 changed: 'context' -> 'presentations'
# Word at index 138 changed: 'presentations' -> 'of'
# Word at index 139 changed: 'of' -> 'abdominal'
# Word at index 140 changed: 'abdominal' -> 'masses'
# Word at index 141 changed: 'masses' -> 'in'
# Word at index 142 changed: 'in' -> 'secondary'
# Word at index 143 changed: 'secondary' -> 'care'
# Word at index 144 changed: 'care' -> 'can'
# Word at index 145 changed: 'can' -> 'cover'
# Word at index 146 changed: 'cover' -> 'a'
# Word at index 147 changed: 'a' -> 'broad'
# Word at index 148 changed: 'broad' -> 'range'
# Word at index 149 changed: 'range' -> 'of'
# Word at index 150 changed: 'of' -> 'pathologies'
# Word at index 151 changed: 'pathologies' -> 'in'
# Word at index 152 changed: 'in' -> 'the'
# Word at index 153 changed: 'the' -> 'acute'
# Word at index 154 changed: 'acute' -> 'setting'
# Word at index 155 changed: 'setting' -> 'you'
# Word at index 156 changed: 'you' -> 'are'
# Word at index 157 changed: 'are' -> 'most'
# Word at index 158 changed: 'most' -> 'likely'
# Word at index 159 changed: 'likely' -> 'to'
# Word at index 160 changed: 'to' -> 'encounter'
# Word at index 161 changed: 'encounter' -> 'abdominal'
# Word at index 162 changed: 'abdominal' -> 'masses'
# Word at index 163 changed: 'masses' -> 'in'
# Word at index 164 changed: 'in' -> 'the'
# Word at index 165 changed: 'the' -> 'emergency'
# Word at index 166 changed: 'emergency' -> 'department'
# Word at index 167 changed: 'department' -> 'or'
# Word at index 168 changed: 'or' -> 'acute'
# Word at index 169 changed: 'acute' -> 'surgical'
# Word at index 170 changed: 'surgical' -> 'units'
# Word at index 171 changed: 'units' -> 'where'
# Word at index 172 changed: 'where' -> 'the'
# Word at index 173 changed: 'the' -> 'mass'
# Word at index 174 changed: 'mass' -> 'is'
# Word at index 175 changed: 'is' -> 'usually'
# Word at index 176 changed: 'usually' -> 'accompanied'
# Word at index 177 changed: 'accompanied' -> 'with'
# Word at index 178 changed: 'with' -> 'abdominal'
# Word at index 179 changed: 'abdominal' -> 'pain'
# Word at index 180 changed: 'pain' -> 'in'
# Word at index 181 changed: 'in' -> 'these'
# Word at index 182 changed: 'these' -> 'situations'
# Word at index 183 changed: 'situations' -> 'a'
# Word at index 184 changed: 'a' -> 'thorough'
# Word at index 185 changed: 'thorough' -> 'history'
# Word at index 186 changed: 'history' -> 'and'
# Word at index 187 changed: 'and' -> 'abdominal'
# Word at index 188 changed: 'abdominal' -> 'examination'
# Word at index 189 changed: 'examination' -> 'is'
# Word at index 190 changed: 'is' -> 'essential'
# Word at index 191 changed: 'essential' -> 'to'
# Word at index 192 changed: 'to' -> 'help'
# Word at index 193 changed: 'help' -> 'establish'
# Word at index 194 changed: 'establish' -> 'the'
# Word at index 195 changed: 'the' -> 'location'
# Word at index 196 changed: 'location' -> 'and'
# Word at index 197 changed: 'and' -> 'the'
# Word at index 198 changed: 'the' -> 'cause'
# Word at index 199 changed: 'cause' -> 'of'
# Word at index 200 changed: 'of' -> 'the'
# Word at index 201 changed: 'the' -> 'abdominal'
# Word at index 202 changed: 'abdominal' -> 'mass'
# Word at index 203 changed: 'mass' -> 'you'
# Word at index 204 changed: 'you' -> 'may'
# Word at index 205 changed: 'may' -> 'also'
# Word at index 206 changed: 'also' -> 'encounter'
# Word at index 207 changed: 'encounter' -> 'patients'
# Word at index 208 changed: 'patients' -> 'who'
# Word at index 209 changed: 'who' -> 'have'
# Word at index 210 changed: 'have' -> 'bowel'
# Word at index 211 changed: 'bowel' -> 'obstruction'
# Word at index 212 changed: 'obstruction' -> 'secondary'
# Word at index 213 changed: 'secondary' -> 'to'
# Word at index 214 changed: 'to' -> 'an'
# Word at index 215 changed: 'an' -> 'abdominal'
# Word at index 216 changed: 'abdominal' -> 'mass'
# Word at index 217 changed: 'mass' -> 'these'
# Word at index 218 changed: 'these' -> 'patients'
# Word at index 219 changed: 'patients' -> 'are'
# Word at index 220 changed: 'are' -> 'often'
# Word at index 221 changed: 'often' -> 'very'
# Word at index 222 changed: 'very' -> 'unwell'
# Word at index 223 changed: 'unwell' -> 'in'
# Word at index 224 changed: 'in' -> 'addition'
# Word at index 225 changed: 'addition' -> 'to'
# Word at index 226 changed: 'to' -> 'abdominal'
# Word at index 227 changed: 'abdominal' -> 'pain'
# Word at index 228 changed: 'pain' -> 'they'
# Word at index 229 changed: 'they' -> 'often'
# Word at index 230 changed: 'often' -> 'experience'
# Word at index 231 changed: 'experience' -> 'nausea'
# Word at index 232 changed: 'nausea' -> 'vomiting'
# Word at index 233 changed: 'vomiting' -> 'reducedno'
# Word at index 234 changed: 'and' -> 'flatus'
# Word at index 235 changed: 'reducedno' -> 'on'
# Word at index 236 changed: 'flatus' -> 'examination'
# Word at index 237 changed: 'on' -> 'their'
# Word at index 238 changed: 'examination' -> 'abdomen'
# Word at index 239 changed: 'their' -> 'is'
# Word at index 240 changed: 'abdomen' -> 'usually'
# Word at index 241 changed: 'is' -> 'tender'
# Word at index 242 changed: 'usually' -> 'and'
# Word at index 243 changed: 'tender' -> 'bowel'
# Word at index 244 changed: 'and' -> 'sounds'
# Word at index 245 changed: 'bowels' -> 'are'
# Word at index 246 changed: 'sounds' -> 'usually'
# Word at index 247 changed: 'are' -> 'absent'
# Word at index 248 changed: 'usually' -> 'or'
# Word at index 249 changed: 'absent' -> 'tinkling'
# Word at index 250 changed: 'or' -> 'this'
# Word at index 251 changed: 'tinkling' -> 'is'
# Word at index 252 changed: 'this' -> 'a'
# Word at index 253 changed: 'is' -> 'surgical'
# Word at index 254 changed: 'surgical' -> 'emergency'
# Word at index 255 changed: 'emergency' -> 'due'
# Word at index 256 changed: 'due' -> 'to'
# Word at index 257 changed: 'to' -> 'the'
# Word at index 258 changed: 'the' -> 'impending'
# Word at index 259 changed: 'impending' -> 'risk'
# Word at index 260 changed: 'risk' -> 'of'
# Word at index 261 changed: 'of' -> 'bowel'
# Word at index 262 changed: 'bowel' -> 'perforation'
# Word at index 263 changed: 'perforation' -> 'causes'
# Word at index 264 changed: 'causes' -> 'of'
# Word at index 265 changed: 'of' -> 'abdominal'
# Word at index 266 changed: 'abdominal' -> 'masses'
# Word at index 267 changed: 'masses' -> 'can'
# Word at index 268 changed: 'can' -> 'be'
# Word at index 269 changed: 'be' -> 'broken'
# Word at index 270 changed: 'broken' -> 'down'
# Word at index 271 changed: 'down' -> 'into'
# Word at index 272 changed: 'into' -> 'malignant'
# Word at index 273 changed: 'malignant' -> 'and'
# Word at index 274 changed: 'and' -> 'nonmalignant'
# Word at index 275 changed: 'nonmalignant' -> 'causes'
# Word at index 276 changed: 'causes' -> 'nonmalignant'
# Word at index 277 changed: 'nonmalignant' -> 'disease'
# Word at index 278 changed: 'disease' -> 'processes'
# Word at index 279 changed: 'processes' -> 'include'
# Word at index 280 changed: 'include' -> 'hernias'
# Word at index 281 changed: 'hernias' -> 'abdominal'
# Word at index 282 changed: 'abdominal' -> 'aortic'
# Word at index 283 changed: 'aortic' -> 'aneurysm'
# Word at index 284 changed: 'aneurysm' -> 'diverticulitis'
# Word at index 285 changed: 'diverticulitis' -> 'crohns'
# Word at index 286 changed: 'crohns' -> 'disease'
# Word at index 287 changed: 'disease' -> 'ovarian'
# Word at index 288 changed: 'and' -> 'cyst'
# Word at index 289 changed: 'ovarian' -> 'in'
# Word at index 290 changed: 'cyst' -> 'women'
# Word at index 291 changed: 'in' -> 'various'
# Word at index 292 changed: 'women' -> 'malignancies'
# Word at index 293 changed: 'various' -> 'can'
# Word at index 294 changed: 'malignancies' -> 'present'
# Word at index 295 changed: 'can' -> 'with'
# Word at index 296 changed: 'present' -> 'an'
# Word at index 297 changed: 'with' -> 'abdominal'
# Word at index 298 changed: 'an' -> 'mass'
# Word at index 299 changed: 'abdominal' -> 'including'
# Word at index 300 changed: 'mass' -> 'stomach'
# Word at index 301 changed: 'including' -> 'colorectal'
# Word at index 302 changed: 'stomach' -> 'renal'
# Word at index 303 changed: 'colorectal' -> 'liver'
# Word at index 304 changed: 'renal' -> 'cancers'
# Word at index 305 changed: 'and' -> 'paediatric'
# Word at index 306 changed: 'liver' -> 'care'
# Word at index 307 changed: 'cancers' -> 'context'
